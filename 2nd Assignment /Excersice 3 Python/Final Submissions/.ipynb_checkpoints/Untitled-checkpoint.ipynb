# %%
"...
"==
"..."
# Out:
#   File "<ipython-input-1-120d2d8963d5>", line 1
#     "...
# ...

# %%
"..."=="...
"
# Out:
#   File "<ipython-input-2-b9999c1d08d0>", line 1
#     "..."=="...
# ...

# %%
a="..."

# %%
a= "..."

# %%
sml="..."

# %%
new="..."

# %%
sml==new
# Out:
# False

# %%
python="..."

# %%
python==new
# Out:
# False

# %%
py="...
"
# Out:
#   File "<ipython-input-11-17f74c31c4d3>", line 1
#     py="...
# ...

# %%
py= "..."

# %%
l="..."

# %%
forl==py
# Out:
# False

# %%
print(3)
# Out:
# 3

# %%
a="..."

# %%
b="..."

# %%
a==b
# Out:
# True

# %%
c="..."

# %%
d="..."

# %%
c==d
# Out:
# True

# %%
ml="DDLLLLDDLLLLLLLLLLLUULLUULLLLLLUULLUURRUULLUUUULLDDLLLLUULLDDLLUUUUUULLUULLDDDDLLLLDDLLLLDDRRDDDDDDLLDDRRDDLLLLDDLLLLUURR"

# %%
dd="DDLLLLDDLLLLLLLLLLLLUULLUULLLLLLUULLUURRUULLUUUULLDDLLLLUULLDDLLUUUUUULLUULLDDDDLLLLDDLLLLDDRRDDDDDDLLDDRRDDLLLLDDLLLLUURR"

# %%
ml==dd
# Out:
# False
